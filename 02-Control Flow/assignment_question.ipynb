# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input as password and prints it.

# %%
from getpass import getpass

# Your code here
INPUT = getpass("Please Enter something: ")
print(INPUT)
print(type(INPUT))
# Out:
# Ayush@0519
# <class 'str'>

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Please Enter The Number:"))
if num>0:
    print("The Entered Numbered is Positive.")
elif num<0:
    print("The Entered number is Negative.")
else :
    print("The Entered Number is Zero")
# Out:
# The Entered Number is Zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
# nums = set()
# for i in range(3):
#     n = int(input(f"Enter number {i+1}: "))
#     nums.add(n)
# print("The largest number is:", max(nums))

num1 = float(input("Enter the first Number:"))
num2 = float(input("Enter the Second Number:"))
num3 = float(input("Enter the Third Number:"))

# if (num1>num2) and (num1>num3):
#     print(f"{num1} is Largest among all three numbers.")
# elif (num2>num3) and (num2>num1):
#     print(f"{num2} is Largest of all the three numbers.")
# else :
#     print(f"{num3} is Largest of all the three Numbers.")

if (num1>num2) and (num1>num3):
    largest = num1;
elif (num2>num1) and (num2>num3):
    largest = num2;
else :
    largest= num3;
print(f"The largest number among all three is {largest}")
# Out:
# The largest number among all three is 100.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial(n):
    if n==0:
        return 1
    else:
        return n*factorial(n-1)
    
num= int(input("Enter A number:"))
print(f'The factorial of {num} is {factorial(num)}')
# Out:
# The factorial of 4 is 24

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
integer_var = 10;
float_var= 2.33;
string_var ="Ayush"
boolean_var = True

print(f"Integer value :{integer_var} ,type:{type(integer_var)}")
print(f"Integer value :{float_var} ,type:{type(float_var)}")
print(f"Integer value :{string_var} ,type:{type(string_var)}")
print(f"Integer value :{boolean_var} ,type:{type(boolean_var)}")
# Out:
# Integer value :10 ,type:<class 'int'>
# Integer value :2.33 ,type:<class 'float'>
# Integer value :Ayush ,type:<class 'str'>
# Integer value :True ,type:<class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a = 5;
b= 34;
print(f'Before Swapping a:{a} and b:{b}')

#Swapping
a,b = b,a;
print(f"After Swapping a: {a} and b:{b}")
# Out:
# Before Swapping a:5 and b:34
# After Swapping a: 34 and b:5

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
cel = int(input("Enter the temp in Celsius:"))
fah= (9/5*cel)+32;
print(f'{cel} degree celsius is {fah} degree in fahrenheit')
# Out:
# 75 degree celsius is 167.0 degree in fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
string1 ="Namaste";
string2 = "Ayush";

full_str = string1 + " " + string2 + "!";
print(full_str)
# Out:
# Namaste Ayush!

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var = bool(0)

if isinstance(var,float):
    print(f"{var} is a float")
elif isinstance(var , str):
    print(f"{var} is a String")

elif isinstance(var , bool):
    print(f"{var} is Boolean.")
elif isinstance(var,int):
    print(f"{var} is integer");
# Out:
# False is Boolean.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here;
num1 = int(input("Enter The First Number:"))
num2 = int(input("Enter The Second Number:"))
op =  input("Enter the operator +,-,/,%,* :");

if op=="+":
    print(f"Addition : {num1+num2}")
elif op=="-":
    print(f"Subtraction : {num1-num2}")
elif op=="*":
    print(f"Multiplication : {num1*num2}")
elif op=="/":
    if num2==0:
        print("The Division is Invalid !")
    else:
        print(f"Division : {num1/num2}")
elif op=="%":
    if num2==0:
        print( "Enable to find the Remainder !" )
    else:
        print(f"The remainder is  : {num1%num2}")
# Out:
# Multiplication : 625

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
num1 = int(input("enter The first Number:"))
num2 = int(input("enter The Second Number:"))

if (num1==num2)  :
    result = f"{num1} is equal to {num2}" 
elif (num1!=num2)  :
      if (num1>num2) :
        print(f"{num1} is not equal to {num2}")
        result = f"{num1} Is greater than {num2}" 
      else:
        print(f"{num1} is not equal to {num2}")
        result = f"{num1} is Lesser than {num2}" 
      

    


print(result)
# Out:
# 23 is not equal to 14
# 23 Is greater than 14

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
a =True;
b= False;

print(f"True and False: {a and b}");
print(f"True or False: {a or b}");
print(f"Not True: {not a}");
# Out:
# True and False: False
# True or False: True
# Not True: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square root of a number.

# %%
# Your code here;
num = int(input("Enter The Number:"));
from math import sqrt

result = sqrt(num)
print(result)
# Out:
# 4.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter the number"));

if num%2 == 0:
    print(f"The {num} is Even");
else :
    print(f"The {num} is odd")
# Out:
# The 34 is Even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here:

def naturnal_sum(n):
    sum = 0
    for i in range (n+1):
        sum = sum +i

    return sum
 
print(f'The sum of first 10 natural numbers is {naturnal_sum(10)} ')
# Out:
# The sum of first 10 natural numbers is 55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter A year :"))
if (year % 4 ==0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is Leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2035 is not a leap year.

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = input("Enter A String: ")
reversed_string = string[::-1]
print(f"The reverses String is : {reversed_string}")
# Out:
# The reverses String is : hsuyA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
string = input("Enter The String: ")
string3 = string.lower()
if string3 == string3[::-1]:
    print(f"{string} is a Palindrome")
else:
    print(f"{string} is not a Palindrome.")
# Out:
# DAad is a Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted List: {numbers}")
# Out:
# Sorted List: [12, 23, 32, 32, 36, 45, 76, 454]
